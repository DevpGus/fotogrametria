# %% [markdown]
# ## Reconstrução 3D - Open3D.
#
# > O objetivo deste _notebook_ é avaliar a reconstrução 3d obtida pelos passos anteriores de: Escala (s), Profundidade (z) e Filtragem.
# >
# > O _input_ do método a seguir é o modelo _.plt_ que descreve as posições _(x, y, z)_ de um determinado pixel e sua cor associada _RGB_.

# %%
import open3d as o3d
import os
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def show_3d(caminho_arquivo="./results/models/model.ply"):
    """
    Abre uma janela interativa de alto desempenho para explorar o modelo 3D.
    Permite zoom, rotação livre e iluminação dinâmica.
    """
    if not os.path.exists(caminho_arquivo):
        print(f"Erro: O arquivo {caminho_arquivo} não foi encontrado.")
        return
        
    print(f"Carregando {caminho_arquivo} no visualizador Open3D...")
    
    # Ler o arquivo PLY
    pcd = o3d.io.read_point_cloud(caminho_arquivo)
    
    # Estimar normais para que a iluminação reaja corretamente ao relevo
    pcd.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
    
    # Abrir a interface
    o3d.visualization.draw_geometries([pcd], 
                                      window_name="Visualizador de Fotogrametria",
                                      width=1024, height=768,
                                      left=50, top=50,
                                      point_show_normal=False)

# %%
path = '../results/models/model.ply'

# %%
show_3d(path)
# Out:
# Carregando ../results/models/model.ply no visualizador Open3D...
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: Identificador inválido.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: Não há suporte para a operação de transformação solicitada.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: Não há suporte para a operação de transformação solicitada.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: Identificador inválido.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: Não há suporte para a operação de transformação solicitada.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: Identificador inválido.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: Não há suporte para a operação de transformação solicitada.
# [Open3D WARNING] GLFW Error: WGL: Failed to make context current: Não há suporte para a operação de transformação solicitada.
# ...
